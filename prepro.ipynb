# %% [markdown]
# <a href="https://colab.research.google.com/github/ADGGi/CP2/blob/main/prepro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #데이터 나눠보기(-> celeb별 대화데이터)

# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/CP2/통합문서3.csv')

# %%
df.head()
# Out:
#            date   time celeb  ...                       comments file Unnamed: 6
# 0  Jul 12, 2021  20:39  VAYA  ...                     님이 참여했습니다.  NaN        NaN
# 1  Jul 12, 2021  20:40  VAYA  ...                          사랑해요🖤  NaN        NaN
# 2  Jul 12, 2021  20:40  VAYA  ...                     님이 참여했습니다.  NaN        NaN
# 3  Jul 12, 2021  20:41  VAYA  ...                     님이 참여했습니다.  NaN        NaN
# 4  Jul 12, 2021  20:41  VAYA  ...  단톡 전용 인스타 대체일지... 자려고했는데 파들..  NaN        NaN
#
# [5 rows x 7 columns]

# %%
df = df[['date', 'time', 'celeb', 'code', 'comments', 'file']]
df
# Out:
#                date   time celeb  code                       comments file
# 0      Jul 12, 2021  20:39  VAYA  KAMF                     님이 참여했습니다.  NaN
# 1      Jul 12, 2021  20:40  VAYA  KAMF                          사랑해요🖤  NaN
# 2      Jul 12, 2021  20:40  VAYA  MLSC                     님이 참여했습니다.  NaN
# 3      Jul 12, 2021  20:41  VAYA  ZSOS                     님이 참여했습니다.  NaN
# 4      Jul 12, 2021  20:41  VAYA  MLSC  단톡 전용 인스타 대체일지... 자려고했는데 파들..  NaN
# ...             ...    ...   ...   ...                            ...  ...
# 10328           NaN    NaN   NaN   NaN                            NaN  NaN
# 10329           NaN    NaN   NaN   NaN                            NaN  NaN
# 10330           NaN    NaN   NaN   NaN                            NaN  NaN
# 10331           NaN    NaN   NaN   NaN                            NaN  NaN
# 10332           NaN    NaN   NaN   NaN                            NaN  NaN
#
# [10333 rows x 6 columns]

# %%
df = df[1:10327]

# %%
df['celeb'].unique()
# Out:
# array(['VAYA', 'WKDG', 'XMSQ', 'CJSL', 'DQZB', 'JLDN', 'OSQR', 'JSEU',
#        'LOVM', 'JOPU'], dtype=object)

# %%
celeb_VAYA = df[df['celeb']=='VAYA']
celeb_VAYA.reset_index(drop=True, inplace=True)
celeb_VAYA
# Out:
#               date  ... file
# 0     Jul 12, 2021  ...  NaN
# 1     Jul 12, 2021  ...  NaN
# 2     Jul 12, 2021  ...  NaN
# 3     Jul 12, 2021  ...  NaN
# 4     Jul 12, 2021  ...  NaN
# ...            ...  ...  ...
# 3037  Aug 19, 2021  ...  NaN
# 3038  Aug 19, 2021  ...  NaN
# 3039  Aug 19, 2021  ...  NaN
# 3040  Aug 19, 2021  ...  NaN
# 3041  Aug 19, 2021  ...  NaN
#
# [3042 rows x 6 columns]

# %%
celeb_WKDG = df[df['celeb']=='WKDG']
celeb_WKDG.reset_index(drop=True, inplace=True)
celeb_WKDG
# Out:
#               date  ...                  file
# 0      Jul 9, 2021  ...                   NaN
# 1      Jul 9, 2021  ...  파일_1625760471882.mov
# 2      Jul 9, 2021  ...                   NaN
# 3      Jul 9, 2021  ...                   NaN
# 4      Jul 9, 2021  ...                   NaN
# ...            ...  ...                   ...
# 1710  Aug 19, 2021  ...                   NaN
# 1711  Aug 19, 2021  ...                   NaN
# 1712  Aug 19, 2021  ...                   NaN
# 1713  Aug 19, 2021  ...                   NaN
# 1714  Aug 19, 2021  ...                   NaN
#
# [1715 rows x 6 columns]

# %%
celeb_XMSQ = df[df['celeb']=='XMSQ']
celeb_XMSQ.reset_index(drop=True, inplace=True)
celeb_XMSQ
# Out:
#               date   time celeb  code            comments file
# 0      Jul 8, 2021  21:04  XMSQ  BYZG     코가쿨라 님이 참여했습니다.  NaN
# 1      Jul 8, 2021  21:36  XMSQ  BYZG        ㅎㅇㅎㅇ 안녕하세요~?  NaN
# 2      Jul 8, 2021  21:49  XMSQ  XMSQ       Operator안녕하세용  NaN
# 3      Jul 8, 2021  21:56  XMSQ  BYZG  이제 장마인데 잠이 안오네요 ㅠㅠ  NaN
# 4      Jul 8, 2021  22:00  XMSQ  LBLA          님이 참여했습니다.  NaN
# ...            ...    ...   ...   ...                 ...  ...
# 2280  Aug 19, 2021  11:48  XMSQ  JPGP         오늘은 거래할수있을까  NaN
# 2281  Aug 19, 2021  11:49  XMSQ  ZRAJ              쉐이킷쉐이킷  NaN
# 2282  Aug 19, 2021  11:50  XMSQ  WSFL       오ㅋㅋㅋㅋ 녹차맛 쉐이크  NaN
# 2283  Aug 19, 2021  11:50  XMSQ  WSFL       이제 스파르탄큐만 조지면  NaN
# 2284  Aug 19, 2021  11:50  XMSQ  XMSQ    Operator베개도 팔아야댐  NaN
#
# [2285 rows x 6 columns]

# %%
celeb_CJSL = df[df['celeb']=='CJSL']
celeb_CJSL.reset_index(drop=True, inplace=True)
celeb_CJSL
# Out:
#               date   time  ...                        comments               file
# 0     Jun 12, 2021  23:15  ...                   Operator안녕하세요                NaN
# 1     Jun 12, 2021  23:16  ...    Operator얼리어답터분들 두분만이 새로 까셨군요                NaN
# 2     Jun 12, 2021  23:16  ...                             NaN  Img 1623507379998
# 3     Jun 12, 2021  23:16  ...            Operator요즘 마리 캣타워입니다                NaN
# 4     Jun 12, 2021  23:17  ...                              ㅋㅋ                NaN
# ...            ...    ...  ...                             ...                ...
# 1692  Aug 19, 2021  11:18  ...                  15학점보다는 낫죠...?                NaN
# 1693  Aug 19, 2021  11:32  ...              Operator이게모람!ㅋㅋ 커엽                NaN
# 1694  Aug 19, 2021  11:34  ...                   귀엽네요 마치 저처럼 ㅎ                NaN
# 1695  Aug 19, 2021  11:34  ...                           어맛ㅋㅋㅋ                NaN
# 1696  Aug 19, 2021  11:41  ...  시지비에서 파는 팝콘콤보세트요... 35000원인가..                NaN
#
# [1697 rows x 6 columns]

# %%
celeb_DQZB = df[df['celeb']=='DQZB']
celeb_DQZB.reset_index(drop=True, inplace=True)
celeb_DQZB
# Out:
#              date  ...               file
# 0     Jul 6, 2021  ...                NaN
# 1     Jul 6, 2021  ...                NaN
# 2     Jul 6, 2021  ...                NaN
# 3     Jul 6, 2021  ...                NaN
# 4     Jul 6, 2021  ...                NaN
# ..            ...  ...                ...
# 307  Aug 10, 2021  ...                NaN
# 308  Aug 10, 2021  ...                NaN
# 309  Aug 10, 2021  ...                NaN
# 310  Aug 10, 2021  ...  Img 1628602317413
# 311  Aug 10, 2021  ...                NaN
#
# [312 rows x 6 columns]

# %%
celeb_JLDN = df[df['celeb']=='JLDN']
celeb_JLDN.reset_index(drop=True, inplace=True)
celeb_JLDN
# Out:
#              date   time celeb  code                  comments file
# 0     Jul 7, 2021  14:45  JLDN  CNJO                님이 참여했습니다.  NaN
# 1     Jul 7, 2021  14:45  JLDN  CNJO                    이리오너라~  NaN
# 2     Jul 7, 2021  14:45  JLDN  JLDN        Operatorㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ  NaN
# 3     Jul 7, 2021  14:45  JLDN  JLDN            Operator1빠 나이스  NaN
# 4     Jul 7, 2021  14:46  JLDN  CNJO                      ㄴㅇㅅ~  NaN
# ..            ...    ...   ...   ...                       ...  ...
# 910  Aug 17, 2021  14:18  JLDN  EFYA            과음하시더니....하하..  NaN
# 911  Aug 17, 2021  14:19  JLDN  JLDN        Operatorㅋㅋㅋㅋㅋ아..두야  NaN
# 912  Aug 17, 2021  15:38  JLDN  UNGO  푹쉬시고 쾌차하세요 ㅠㅜ 건강이 먼접니다!!  NaN
# 913  Aug 18, 2021  12:12  JLDN  JLDN        Operator오뱅 아마도 1시!  NaN
# 914  Aug 18, 2021  12:19  JLDN  CNJO                       확인~  NaN
#
# [915 rows x 6 columns]

# %%
celeb_OSQR = df[df['celeb']=='OSQR']
celeb_OSQR.reset_index(drop=True, inplace=True)
celeb_OSQR
# Out:
#             date   time celeb  code         comments file
# 0    Jul 8, 2021  21:36  OSQR  BYZG  코가쿨라 님이 참여했습니다.  NaN
# 1    Jul 8, 2021  21:36  OSQR  BYZG          안녕하세요~?  NaN
# 2    Jul 8, 2021  21:46  OSQR  FZOM       님이 참여했습니다.  NaN
# 3    Jul 8, 2021  21:46  OSQR  FZOM  대장님! 인사박습니다!^^7  NaN
# 4    Jul 9, 2021  07:03  OSQR  NSMB       님이 참여했습니다.  NaN
# ..           ...    ...   ...   ...              ...  ...
# 83  Aug 15, 2021  19:02  OSQR  UPIG       님이 참여했습니다.  NaN
# 84  Aug 15, 2021  19:03  OSQR  UPIG             우와우왕  NaN
# 85  Aug 15, 2021  19:03  OSQR  UPIG      이걸이제알았네 하이용  NaN
# 86  Aug 15, 2021  19:33  OSQR  OSQR    Operator어서와☺️  NaN
# 87  Aug 15, 2021  19:56  OSQR  UPIG                😁  NaN
#
# [88 rows x 6 columns]

# %%
celeb_JSEU = df[df['celeb']=='JSEU']
celeb_JSEU.reset_index(drop=True, inplace=True)
celeb_JSEU
# Out:
#             date   time celeb  code                          comments file
# 0   Aug 13, 2021  15:27  JSEU  NTFC                        님이 참여했습니다.  NaN
# 1   Aug 13, 2021  15:29  JSEU  NTFC            어떻게 나오는지 궁금해서 쳐보는 아무말!  NaN
# 2   Aug 13, 2021  16:46  JSEU  JSEU                Operator {닉네임}님 바보  NaN
# 3   Aug 13, 2021  16:57  JSEU  NQWK                                 앍  NaN
# 4   Aug 13, 2021  16:57  JSEU  NQWK                                 ㅠ  NaN
# 5   Aug 13, 2021  17:05  JSEU  CIUI                               ㅇㅁㅇ  NaN
# 6   Aug 13, 2021  17:06  JSEU  CIUI                   알림이 죄다 안울렸읍니다..  NaN
# 7   Aug 13, 2021  18:37  JSEU  NTFC                               ಠ︵ಠ  NaN
# 8   Aug 13, 2021  18:39  JSEU  BGGQ                                 ?  NaN
# 9   Aug 13, 2021  18:39  JSEU  BGGQ                     갑자기 바보를 박는다구?  NaN
# 10  Aug 13, 2021  18:45  JSEU  JSEU                   Operator몽총이 ㅎ0ㅎ  NaN
# 11  Aug 13, 2021  18:46  JSEU  XLJI                           땅꼬맹이 ㅌㅌ  NaN
# 12  Aug 13, 2021  18:52  JSEU  NTFC       ಠ︵ಠಠ︵ಠಠ︵ಠಠ︵ಠಠ︵ಠಠ︵ಠಠ︵ಠಠ︵ಠಠ︵ಠ  NaN
# 13  Aug 13, 2021  18:52  JSEU  NTFC  내일 방송 안 갈꺼에요! 흥! 가더라도 조용히 있어야겠다!  NaN
# 14  Aug 13, 2021  19:24  JSEU  JSEU         Operator저한테 협박은 안 통해요 ㅋ0ㅋ  NaN
# 15  Aug 13, 2021  19:42  JSEU  NTFC             알았어요.. 몽총이 할께요(´;︵;`)  NaN
# 16  Aug 13, 2021  19:43  JSEU  NTFC           근데 사실 내일 학원 때문에 못가여 ㅋㅋㅋ  NaN
# 17  Aug 13, 2021  19:44  JSEU  JSEU                       Operator몽총이  NaN
# 18  Aug 13, 2021  19:45  JSEU  NTFC                               몽총이  NaN
# 19  Aug 13, 2021  20:41  JSEU  CIUI                              잘자요오  NaN
# 20  Aug 14, 2021  07:39  JSEU  NTFC                           굿모닝이에요!  NaN
# 21  Aug 14, 2021  11:21  JSEU  CIUI                          잘 주무셨나요오  NaN
# 22  Aug 14, 2021  11:21  JSEU  CIUI                         좋은 아침임니다!  NaN
# 23  Aug 14, 2021  15:06  JSEU  SBBO                        님이 참여했습니다.  NaN
# 24  Aug 14, 2021  19:28  JSEU  GXIX                         님이 참여했습니다  NaN
# 25  Aug 15, 2021  06:25  JSEU  CYRB                        님이 참여했습니다.  NaN
# 26  Aug 15, 2021  19:09  JSEU  JSEU                      Operator쫀아쫀아  NaN
# 27  Aug 15, 2021  19:10  JSEU  CIUI       ㅁ..목이 ㅅ..쉰 반ㄴ님...이라..도 좋아요오  NaN
# 28  Aug 15, 2021  19:18  JSEU  XLJI                                쫀저  NaN
# 29  Aug 15, 2021  19:25  JSEU  NQWK                            아무튼 쫀아  NaN
# 30  Aug 15, 2021  19:34  JSEU  BGGQ              7시,,에 쫀아를 박으신다규요? ㅋㅋ  NaN
# 31  Aug 16, 2021  18:14  JSEU  XLJI                          반님바보 (ㅌㅌ  NaN
# 32  Aug 17, 2021  00:02  JSEU  NTFC                     목 빠지게 기다리는중..  NaN
# 33  Aug 17, 2021  01:29  JSEU  NTFC                       -트수 지쳐 잠들다-  NaN
# 34  Aug 17, 2021  21:38  JSEU  CIUI         반님ㅁ,, 배 아픈거 다 낫고 아푸지 맙시다ㅏ  NaN
# 35  Aug 17, 2021  22:00  JSEU  JSEU                      Operator응애..  NaN
# 36  Aug 17, 2021  22:00  JSEU  JSEU               Operator아가반.. 배아파..  NaN
# 37  Aug 17, 2021  22:01  JSEU  CIUI                                 힝  NaN
# 38  Aug 17, 2021  22:01  JSEU  CIUI                           (우는 임티)  NaN
# 39  Aug 17, 2021  22:53  JSEU  NQWK                       푹 쉬셔유....ㅠㅠ  NaN
# 40  Aug 18, 2021  20:02  JSEU  BGGQ                           반님반님 ㅠㅠ  NaN
# 41  Aug 18, 2021  20:02  JSEU  BGGQ                        이제퇴근했어요 ㅠㅠ  NaN
# 42  Aug 18, 2021  20:02  JSEU  BGGQ             트수가 미안해요 화내지 말아주세요 ㅠㅠ  NaN
# 43  Aug 19, 2021  00:12  JSEU  JSEU                     Operator텀블러삿다  NaN
# 44  Aug 19, 2021  00:26  JSEU  NQWK                                 오  NaN
# 45  Aug 19, 2021  00:26  JSEU  NQWK                            머 사셨나여  NaN
# 46  Aug 19, 2021  00:41  JSEU  CIUI                        어떤 디자인인가욧!  NaN
# 47  Aug 19, 2021  01:56  JSEU  BGGQ                      어떤걸로 샀나요? ㅋㅋ  NaN
# 48  Aug 19, 2021  09:27  JSEU  BYZG                          오 어떤거욤??  NaN

# %%
celeb_LOVM = df[df['celeb']=='LOVM']
celeb_LOVM.reset_index(drop=True, inplace=True)
celeb_LOVM
# Out:
#             date   time celeb  code          comments               file
# 0    Aug 9, 2021  15:26  LOVM  COPY        님이 참여했습니다.                NaN
# 1    Aug 9, 2021  15:26  LOVM  COPY                 ?                NaN
# 2    Aug 9, 2021  15:26  LOVM  COPY  네카님이 여기서 왜나와요..?                NaN
# 3    Aug 9, 2021  15:28  LOVM  COPY               NaN  Img 1628490502045
# 4    Aug 9, 2021  15:29  LOVM  LOVM         Operator헉                NaN
# ..           ...    ...   ...   ...               ...                ...
# 83  Aug 18, 2021  02:09  LOVM  COPY            막내 로운이                NaN
# 84  Aug 18, 2021  02:09  LOVM  COPY               NaN  Img 1629220195753
# 85  Aug 18, 2021  02:09  LOVM  COPY             둘째 쏘야                NaN
# 86  Aug 18, 2021  02:10  LOVM  COPY               NaN  Img 1629220215060
# 87  Aug 18, 2021  02:10  LOVM  COPY             첫째 옹이                NaN
#
# [88 rows x 6 columns]

# %%
celeb_JOPU = df[df['celeb']=='JOPU']
celeb_JOPU.reset_index(drop=True, inplace=True)
celeb_JOPU
# Out:
#              date  ...               file
# 0     Aug 7, 2021  ...                NaN
# 1     Aug 8, 2021  ...                NaN
# 2    Aug 10, 2021  ...                NaN
# 3    Aug 10, 2021  ...  Img 1628545098085
# 4    Aug 10, 2021  ...                NaN
# ..            ...  ...                ...
# 130  Aug 18, 2021  ...                NaN
# 131  Aug 18, 2021  ...                NaN
# 132  Aug 18, 2021  ...                NaN
# 133  Aug 18, 2021  ...                NaN
# 134  Aug 19, 2021  ...                NaN
#
# [135 rows x 6 columns]

# %%
celeb_VAYA.to_csv('/content/drive/MyDrive/CP2/celeb_VAYA.csv')
celeb_WKDG.to_csv('/content/drive/MyDrive/CP2/celeb_WKDG.csv')
celeb_XMSQ.to_csv('/content/drive/MyDrive/CP2/celeb_XMSQ.csv')
celeb_CJSL.to_csv('/content/drive/MyDrive/CP2/celeb_CJSL.csv')
celeb_DQZB.to_csv('/content/drive/MyDrive/CP2/celeb_DQZB.csv')
celeb_JLDN.to_csv('/content/drive/MyDrive/CP2/celeb_JLDN.csv')
celeb_OSQR.to_csv('/content/drive/MyDrive/CP2/celeb_OSQR.csv')
celeb_JSEU.to_csv('/content/drive/MyDrive/CP2/celeb_JSEU.csv')
celeb_LOVM.to_csv('/content/drive/MyDrive/CP2/celeb_LOVM.csv')
celeb_JOPU.to_csv('/content/drive/MyDrive/CP2/celeb_JOPU.csv')

# %% [markdown]
# #텍스트 전처리

# %%
df.dtypes
# Out:
# date        object
# time        object
# celeb       object
# code        object
# comments    object
# file        object
# dtype: object

# %%
import re

# %%
def clean(text) :
  #한국어와 알파벳만 남기고 제거
  #4번 이상 반복되는 문자는 2글자만 남김
  #2칸이상 공백은 1칸만 남김
  pattern1 = re.compile(r"[^ A-Za-z0-9가-힣]+")
  pattern2 = re.compile(r"(.)\1{2,}")
  pattern3 = re.compile(r"\s+")

  text = pattern1.sub("", str(text))
  text = pattern2.sub(r"\1" * 2, str(text))
  text = pattern3.sub(" ", str(text))

  return text.strip()

# %%
celeb_VAYA['comments']
# Out:
# 0                                                   사랑해요🖤
# 1                                              님이 참여했습니다.
# 2                                              님이 참여했습니다.
# 3                           단톡 전용 인스타 대체일지... 자려고했는데 파들..
# 4                                            이 님이 참여했습니다.
#                               ...
# 3037                                 아코코 잘하셨어요 쓰담쓰다암 💋💋💋💜
# 3038                                    잘하셨어요 쓰담쓰담 푹 쉬세욥!
# 3039                                           잘하셨어요 쓰담쓰담
# 3040                                             아코 잘하셨어요
# 3041    아코 잘하셨어요 배통통 쓰담문질 \n소화 좀 되면 못주무신 잠 푹 주무세요 \n오늘...
# Name: comments, Length: 3042, dtype: object

# %%
celeb_VAYA['comments'] = [clean(c) for c in celeb_VAYA['comments']]
celeb_VAYA['comments']
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# 0                                                    사랑해요
# 1                                               님이 참여했습니다
# 2                                               님이 참여했습니다
# 3                                단톡 전용 인스타 대체일지 자려고했는데 파들
# 4                                             이 님이 참여했습니다
#                               ...
# 3037                                      아코코 잘하셨어요 쓰담쓰다암
# 3038                                     잘하셨어요 쓰담쓰담 푹 쉬세욥
# 3039                                           잘하셨어요 쓰담쓰담
# 3040                                             아코 잘하셨어요
# 3041    아코 잘하셨어요 배통통 쓰담문질 소화 좀 되면 못주무신 잠 푹 주무세요 오늘도 많이...
# Name: comments, Length: 3042, dtype: object

# %%
celeb_VAYA['comments']
# Out:
# 0                                                    사랑해요
# 1                                               님이 참여했습니다
# 2                                               님이 참여했습니다
# 3                                단톡 전용 인스타 대체일지 자려고했는데 파들
# 4                                             이 님이 참여했습니다
#                               ...
# 3037                                      아코코 잘하셨어요 쓰담쓰다암
# 3038                                     잘하셨어요 쓰담쓰담 푹 쉬세욥
# 3039                                           잘하셨어요 쓰담쓰담
# 3040                                             아코 잘하셨어요
# 3041    아코 잘하셨어요 배통통 쓰담문질 소화 좀 되면 못주무신 잠 푹 주무세요 오늘도 많이...
# Name: comments, Length: 3042, dtype: object

# %%
celeb_VAYA
# Out:
#               date  ... file
# 0     Jul 12, 2021  ...  NaN
# 1     Jul 12, 2021  ...  NaN
# 2     Jul 12, 2021  ...  NaN
# 3     Jul 12, 2021  ...  NaN
# 4     Jul 12, 2021  ...  NaN
# ...            ...  ...  ...
# 3037  Aug 19, 2021  ...  NaN
# 3038  Aug 19, 2021  ...  NaN
# 3039  Aug 19, 2021  ...  NaN
# 3040  Aug 19, 2021  ...  NaN
# 3041  Aug 19, 2021  ...  NaN
#
# [3042 rows x 6 columns]

# %%
print(len(df[df['code']=='VAYA']))
print(len(df[df['code']!='VAYA']))
# Out:
# 336
# 9990
