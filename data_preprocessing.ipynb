# %% [markdown]
# <a href="https://colab.research.google.com/github/zzhenxi/CP2/blob/main/data_preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 데이터 전처리 모듈 만드는 작업중...

# %%
import pandas as pd

# %%
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data = pd.read_excel("/content/drive/MyDrive/my_dataset/AIB_PJ2/M_-__.xlsx", keep_default_na=False)

# %%
data.head()
# Out:
#              날짜     시간 회원 코드        대화 내용 파일(영상, 음성), 사진 여부 긍정/부정 여부
# 0  Jul 12, 2021         VAYA
# 1                20:39  KAMF   님이 참여했습니다.
# 2                20:40  KAMF        사랑해요🖤
# 3                20:40  MLSC   님이 참여했습니다.
# 4                20:41  ZSOS   님이 참여했습니다.

# %% [markdown]
# ## 셀럽 칼럼 만들기

# %%
data.columns
# Out:
# Index(['날짜', '시간', '회원 코드', '대화 내용', '파일(영상, 음성), 사진 여부', '긍정/부정 여부'], dtype='object')

# %%
from numpy.core.numeric import NaN
# 먼저 대화 내용을 제외한 행들 추출 
filter1 = data[(data['날짜'] != '') & (data['회원 코드'] != '')]

# %%
filter1[filter1['회원 코드'] != 'NaN']
# Out:
#                  날짜 시간 회원 코드 대화 내용 파일(영상, 음성), 사진 여부 긍정/부정 여부
# 0      Jul 12, 2021     VAYA
# 244    Jul 13, 2021      NaN
# 473    Jul 14, 2021      NaN
# 583    Jul 15, 2021      NaN
# 684    Jul 16, 2021      NaN
# ...             ... ..   ...   ...               ...      ...
# 10617  Aug 14, 2021      NaN
# 10623  Aug 16, 2021      NaN
# 10628  Aug 17, 2021      NaN
# 10633  Aug 18, 2021      NaN
# 10638  Aug 19, 2021      NaN
#
# [301 rows x 6 columns]

# %%
filter1_2 = filter1.dropna()

# %%
# 셀럽 계정 수
len(filter1_2)
# Out:
# 12

# %%
# 중복 있음 
filter1_2
# Out:
#                  날짜 시간 회원 코드 대화 내용 파일(영상, 음성), 사진 여부 긍정/부정 여부
# 0      Jul 12, 2021     VAYA
# 3082    Jul 9, 2021     WKDG
# 4840    Jul 8, 2021     XMSQ
# 7167   Jun 12, 2021     CJSL
# 8933    Jul 6, 2021     DQZB
# 9058    Jul 9, 2021     DQZB
# 9231   Jul 30, 2021     DQZB
# 9279    Jul 7, 2021     JLDN
# 10234   Jul 8, 2021     OSQR
# 10341  Aug 13, 2021     JSEU
# 10398   Aug 9, 2021     LOVM
# 10495   Aug 7, 2021     JOPU

# %%
# 중복 없애기 
filter1_2_dropdu = filter1_2.drop_duplicates(['회원 코드'])

# %%
filter1_2_dropdu
# Out:
#                  날짜 시간 회원 코드 대화 내용 파일(영상, 음성), 사진 여부 긍정/부정 여부
# 0      Jul 12, 2021     VAYA
# 3082    Jul 9, 2021     WKDG
# 4840    Jul 8, 2021     XMSQ
# 7167   Jun 12, 2021     CJSL
# 8933    Jul 6, 2021     DQZB
# 9279    Jul 7, 2021     JLDN
# 10234   Jul 8, 2021     OSQR
# 10341  Aug 13, 2021     JSEU
# 10398   Aug 9, 2021     LOVM
# 10495   Aug 7, 2021     JOPU

# %%
# 셀럽 수 다시 구해봤다. (잘 나옴)
len(filter1_2_dropdu)
# Out:
# 10

# %%
filter1_2_dropdu = filter1_2_dropdu[['날짜', '회원 코드']]

# %%
filter1_2_dropdu
# Out:
#                  날짜 회원 코드
# 0      Jul 12, 2021  VAYA
# 3082    Jul 9, 2021  WKDG
# 4840    Jul 8, 2021  XMSQ
# 7167   Jun 12, 2021  CJSL
# 8933    Jul 6, 2021  DQZB
# 9279    Jul 7, 2021  JLDN
# 10234   Jul 8, 2021  OSQR
# 10341  Aug 13, 2021  JSEU
# 10398   Aug 9, 2021  LOVM
# 10495   Aug 7, 2021  JOPU

# %% [markdown]
# ### 특정 셀럽에 대한 내용이 시작하는 part 찾기

# %%
# 먼저 날짜와 회원코드가 들어간 튜플 리스트를 만들어 줍니다.

# %%
celeb_list = []
celeb_index_list = []
for index, row in filter1_2_dropdu.iterrows():
  celeb_list.append((row['날짜'], row['회원 코드']))
  celeb_index_list.append(index)

# %%
celeb_list
# Out:
# [('Jul 12, 2021', 'VAYA'),
#  ('Jul 9, 2021', 'WKDG'),
#  ('Jul 8, 2021', 'XMSQ'),
#  ('Jun 12, 2021', 'CJSL'),
#  ('Jul 6, 2021', 'DQZB'),
#  ('Jul 7, 2021', 'JLDN'),
#  ('Jul 8, 2021', 'OSQR'),
#  ('Aug 13, 2021', 'JSEU'),
#  ('Aug 9, 2021', 'LOVM'),
#  ('Aug 7, 2021', 'JOPU')]

# %%
celeb_index_list
# Out:
# [0, 3082, 4840, 7167, 8933, 9279, 10234, 10341, 10398, 10495]

# %% [markdown]
# ### celeb 컬럼 만들어 주기

# %%
# 리스트를 만들어 줬으니 data에 컬럼을 만들어 보겠습니다.

# %%
plus_celeb = data

# %%
plus_celeb
# Out:
#                  날짜  ... 파일(영상, 음성), 사진 여부
# 0      Jul 12, 2021  ...
# 1                    ...
# 2                    ...
# 3                    ...
# 4                    ...
# ...             ...  ...               ...
# 10635                ...
# 10636                ...
# 10637                ...
# 10638  Aug 19, 2021  ...
# 10639                ...
#
# [10640 rows x 5 columns]

# %%
# 필요없는 열 정리 (이건 내가 데이터 잘못 가져와서 임의로 정리해준 것)
# plus_celeb = plus_celeb.drop(columns = ['긍정/부정 여부'])

# %%
plus_celeb['celeb'] = ''

# %%
plus_celeb # celeb 열이 추가되었음
# Out:
#                  날짜     시간  ... 파일(영상, 음성), 사진 여부 celeb
# 0      Jul 12, 2021         ...
# 1                    20:39  ...
# 2                    20:40  ...
# 3                    20:40  ...
# 4                    20:41  ...
# ...             ...    ...  ...               ...   ...
# 10635                17:38  ...
# 10636                18:03  ...
# 10637                18:15  ...
# 10638  Aug 19, 2021         ...
# 10639                02:43  ...
#
# [10640 rows x 6 columns]

# %%
plus_celeb.loc[0:3082, ['celeb']] = 1

# %%
plus_celeb
# Out:
#                  날짜     시간  ... 파일(영상, 음성), 사진 여부 celeb
# 0      Jul 12, 2021         ...                       1
# 1                    20:39  ...                       1
# 2                    20:40  ...                       1
# 3                    20:40  ...                       1
# 4                    20:41  ...                       1
# ...             ...    ...  ...               ...   ...
# 10635                17:38  ...
# 10636                18:03  ...
# 10637                18:15  ...
# 10638  Aug 19, 2021         ...
# 10639                02:43  ...
#
# [10640 rows x 6 columns]

# %%
# 셀렙 이름 붙여주기 위한 코드 (index가 끝까지 있어야 범위 설정 가능!)
index_with_last = celeb_index_list
index_with_last.append(len(plus_celeb)-1)

# %%
index_with_last
# Out:
# [0, 3082, 4840, 7167, 8933, 9279, 10234, 10341, 10398, 10495, 10639]

# %% [markdown]
# 헷갈릴까봐 기록
# index_with_last는 celec컬럼에 셀럽 이름 추가해주기 위해 만든 리스트이고, celeb_index_list는 해당 셀럽의 대화방 시작을 가리키는 인덱스 리스트이다.

# %%
for i in range(len(index_with_last)-1):
  index_from = index_with_last[i] # 3082
  index_to = index_with_last[i+1] # 4840
  who = celeb_list[i][1] # 셀럽 누구인지 i는 index만 모아놓은 list의 순서(넘버)를 말함. 
  plus_celeb.loc[index_from+1:index_to, ['celeb']] = who # 0에서 3081까지 celeb열 값에 who(셀럽 이름) 추가

# %%
plus_celeb
# Out:
#                  날짜     시간  ... 파일(영상, 음성), 사진 여부 celeb
# 0      Jul 12, 2021         ...                    VAYA
# 1                    20:39  ...                    VAYA
# 2                    20:40  ...                    VAYA
# 3                    20:40  ...                    VAYA
# 4                    20:41  ...                    VAYA
# ...             ...    ...  ...               ...   ...
# 10635                17:38  ...                    JOPU
# 10636                18:03  ...                    JOPU
# 10637                18:15  ...                    JOPU
# 10638  Aug 19, 2021         ...                    JOPU
# 10639                02:43  ...                    JOPU
#
# [10640 rows x 6 columns]
